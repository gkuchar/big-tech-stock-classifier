# %% [markdown]
# # Big Tech Stock Classifier
# ## This model will predict which of the 'Big Tech' stocks will have the 'best' day in the stock market tomorrow (not financial advice)
# ## 'Big Tech' Stocks = NVDA, AAPL, MSFT, AMZN, META, GOOGL, TSLA, AMD
# ### TCU Machine Learning course final project - By Griffin Kuchar Spring 2026
